# %% [markdown]
# - package TFPnPSolver into a PR for LION
# - Show how it fits into the LION interface
# - write example script (like LPD.py)
# - document API

# %% [markdown]
# Made pull request for FBPConv
